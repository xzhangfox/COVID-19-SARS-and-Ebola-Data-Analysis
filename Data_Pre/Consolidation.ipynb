# %%
from os import chdir
from glob import glob
import pandas as pd

# %%
# Produce a single CSV after combining all files
def produceOneCSV(list_of_files, file_out):
   # Consolidate all CSV files into one object
   result_obj = pd.concat([pd.read_csv(file) for file in list_of_files])
   # Convert the above object into a csv file and export
   result_obj.to_csv(file_out, index=False, encoding="utf-8")

# Move to the path that holds our CSV files
csv_file_path = "/Users/Fox/Desktop/Data Science/Data Visualization/Project2/Data/COVID-19-master/csse_covid_19_data/csse_covid_19_daily_reports"
chdir(csv_file_path)

# List all CSV files in the working dir
file_pattern = "csv"
list_of_files = [file for file in glob('*.{}'.format(file_pattern))]
#print(list_of_files)

# %%
file_out = "/Users/Fox/Desktop/Data Science/Data Visualization/Project2/Data/Consolidation.csv"
produceOneCSV(list_of_files, file_out)

# %%
df = pd.read_csv(file_out, index_col=None)

# %%
df
# Out:
#                             Province/State  Country/Region  \
# 0                                    Hubei  Mainland China
# 1                                Guangdong  Mainland China
# 2                                    Henan  Mainland China
# 3                                      NaN     South Korea
# 4                                 Zhejiang  Mainland China
# ...                                    ...             ...
# 7612                    Northern Territory       Australia
# 7613  Lackland, TX (From Diamond Princess)              US
# 7614                 Montgomery County, TX              US
# 7615     Omaha, NE (From Diamond Princess)              US
# 7616    Travis, CA (From Diamond Princess)              US
#
#               Last Update  Confirmed  Deaths  Recovered  Latitude  Longitude
# 0     2020-02-26T14:13:10    65187.0  2615.0    20969.0       NaN        NaN
# 1     2020-02-26T10:33:02     1347.0     7.0      851.0       NaN        NaN
# ...

# %%
#N=0
#for i in df["Last Update"]:
#    filtered_value = filter(lambda ch: ch in '0123456789.-: ', i)
#    df["Last Update"][N]=''.join(list(filtered_value))
#    N=N+1

#crazystring = '2020-02-24T23:33:02'
#new_crazy = filter(lambda ch: ch in '0123456789.-: ', crazystring)
#print(''.join(list(new_crazy)))

# %%
#df.loc[df['Last Update'] == '2020-03-06T04:33:03']
drop3_13=df[df['Last Update'].str.contains('2020-03-13')]
drop3_13
# Out:
#         Province/State Country/Region          Last Update  Confirmed  Deaths  \
# 2201  Diamond Princess    Cruise Ship  2020-03-13T14:13:25      696.0     7.0
# 2216             Hebei          China  2020-03-13T11:09:03      318.0     6.0
# 2253            Shanxi          China  2020-03-13T11:09:03      133.0     0.0
# 2419               NaN         Bhutan  2020-03-13T22:22:02        1.0     0.0
# 2430               NaN       Holy See  2020-03-13T22:22:02        1.0     0.0
# ...                ...            ...                  ...        ...     ...
# 6409               NaN          Nepal  2020-03-13T22:22:03        1.0     0.0
# 6503             Hebei          China  2020-03-13T11:09:03      318.0     6.0
# 6551            Shanxi          China  2020-03-13T11:09:03      133.0     0.0
# 6713               NaN       Holy See  2020-03-13T22:22:02        1.0     0.0
# 6714               NaN          Nepal  2020-03-13T22:22:03        1.0     0.0
#
# ...

# %%
drop3_13.index
# Out:
# Int64Index([2201, 2216, 2253, 2419, 2430, 2434, 2442, 2476, 2488, 2523,
#             ...
#             5721, 5722, 6198, 6240, 6408, 6409, 6503, 6551, 6713, 6714],
#            dtype='int64', length=132)

# %%
df = df.drop(drop3_13.index)
df
# Out:
#                             Province/State  Country/Region  \
# 0                                    Hubei  Mainland China
# 1                                Guangdong  Mainland China
# 2                                    Henan  Mainland China
# 3                                      NaN     South Korea
# 4                                 Zhejiang  Mainland China
# ...                                    ...             ...
# 7612                    Northern Territory       Australia
# 7613  Lackland, TX (From Diamond Princess)              US
# 7614                 Montgomery County, TX              US
# 7615     Omaha, NE (From Diamond Princess)              US
# 7616    Travis, CA (From Diamond Princess)              US
#
#               Last Update  Confirmed  Deaths  Recovered  Latitude  Longitude
# 0     2020-02-26T14:13:10    65187.0  2615.0    20969.0       NaN        NaN
# 1     2020-02-26T10:33:02     1347.0     7.0      851.0       NaN        NaN
# ...

# %%
df3_13=pd.read_csv("/Users/Fox/Desktop/Data Science/Data Visualization/Project2/Data/3_13.csv")
df3_13
# Out:
#     Province/State         Country/Region Last Update  Confirmed  Deaths  \
# 0              NaN               Thailand   3/13/2020         82       1
# 1              NaN                  Japan   3/13/2020        773      19
# 2              NaN              Singapore   3/13/2020        212       0
# 3              NaN                  Nepal   3/13/2020          1       0
# 4              NaN               Malaysia   3/13/2020        238       0
# ..             ...                    ...         ...        ...     ...
# 496            NaN                 Jersey   3/13/2020          0       0
# 497            NaN            Puerto Rico   3/13/2020          0       0
# 498            NaN  Republic of the Congo   3/13/2020          0       0
# 499            NaN            The Bahamas   3/13/2020          0       0
# 500            NaN             The Gambia   3/13/2020          0       0
#
#      Recovered  Latitude  Longitude
# 0           35   15.0000   101.0000
# ...

# %%
df = df.append(df3_13, ignore_index = True)

# %%
# Unify the time format
df["Last Update"] = pd.to_datetime(df["Last Update"])
#df['weekday'] = df['time'].dt.weekday
#df['hour'] = df['time'].dt.hour
#df['minute'] = df['time'].dt.minute
# Unify the name of China
df = df.replace(to_replace='Mainland China', value='China', regex=True)
# sort by date
df = df.sort_values(by=['Last Update'])
df
# Out:
#      Province/State    Country/Region         Last Update  Confirmed  Deaths  \
# 3870          Hunan             China 2020-01-22 17:00:00        4.0     NaN
# 3861      Guangdong             China 2020-01-22 17:00:00       26.0     NaN
# 3869          Hubei             China 2020-01-22 17:00:00      444.0    17.0
# 3868      Hong Kong         Hong Kong 2020-01-22 17:00:00        NaN     NaN
# 3867          Henan             China 2020-01-22 17:00:00        5.0     NaN
# ...             ...               ...                 ...        ...     ...
# 6368       Colorado                US 2020-03-21 23:13:18      390.0     4.0
# 6478       Delaware                US 2020-03-21 23:13:18       45.0     0.0
# 6574            NaN        Cape Verde 2020-03-21 23:43:02        1.0     0.0
# 6589            NaN            Uganda 2020-03-21 23:43:02        1.0     0.0
# 6585            NaN  Papua New Guinea 2020-03-21 23:43:02        1.0     0.0
#
#       Recovered  Latitude  Longitude
# ...

# %%
df.to_csv("/Users/Fox/Desktop/Data Science/Data Visualization/Project2/Data/Consolidation_Before_Mar22.csv",index=None)

# %%
# Since the format of daily report differs from the data before March 22, 
# therefore I modify my codes to consolidate those sets of data
d = {'Province/State':[],'Country/Region':[],'Last Update':[],
     'Confirmed':[],'Deaths':[],'Recovered':[],'Latitude':[],'Longitude':[]}
df1=pd.DataFrame(data=d)

# %%
df1
# Out:
# Empty DataFrame
# Columns: [Province/State, Country/Region, Last Update, Confirmed, Deaths, Recovered, Latitude, Longitude]
# Index: []

# %%
# Produce a single CSV after combining all files
def produceOneCSV(list_of_files, file_out):
   # Consolidate all CSV files into one object
   result_obj = pd.concat([pd.read_csv(file) for file in list_of_files])
   # Convert the above object into a csv file and export
   result_obj.to_csv(file_out, index=False, encoding="utf-8")

# Move to the path that holds our CSV files
csv_file_path = "/Users/Fox/Desktop/Data Science/Data Visualization/Project2/Data/Daily3_22_"
chdir(csv_file_path)

# List all CSV files in the working dir
file_pattern = "csv"
list_of_files = [file for file in glob('*.{}'.format(file_pattern))]
#print(list_of_files)

# %%
file_out = "/Users/Fox/Desktop/Data Science/Data Visualization/Project2/Data/Daily3_22_/Consolidation/Consolidation.csv"
produceOneCSV(list_of_files, file_out)

# %%
df2 = pd.read_csv(file_out, index_col=None)

# %%
df2
# Out:
#           FIPS                Admin2        Province_State Country_Region  \
# 0      45001.0             Abbeville        South Carolina             US
# 1      22001.0                Acadia             Louisiana             US
# 2      51001.0              Accomack              Virginia             US
# 3      16001.0                   Ada                 Idaho             US
# 4      19001.0                 Adair                  Iowa             US
# ...        ...                   ...                   ...            ...
# 10244      NaN                   NaN                   NaN          Syria
# 10245      NaN                   NaN                   NaN    Timor-Leste
# 10246      NaN                   NaN                   NaN         Uganda
# 10247  11001.0  District of Columbia  District of Columbia             US
# 10248  53023.0       Garfield County            Washington             US
#
#                Last_Update        Lat       Long_  Confirmed  Deaths  \
# ...

# %%
df1['Country/Region']=(df2['Country_Region'].values)
df1['Province/State']=(df2['Province_State'].values)
df1['Last Update']=(df2['Last_Update'].values)
df1['Latitude']=(df2['Lat'].values)
df1['Longitude']=(df2['Long_'].values)
df1['Confirmed']=(df2['Confirmed'].values)
df1['Deaths']=(df2['Deaths'].values)
df1['Recovered']=(df2['Recovered'].values)

# %%
df1
# Out:
#              Province/State Country/Region          Last Update  Confirmed  \
# 0            South Carolina             US  2020-03-24 23:37:31          1
# 1                 Louisiana             US  2020-03-24 23:37:31          2
# 2                  Virginia             US  2020-03-24 23:37:31          1
# 3                     Idaho             US  2020-03-24 23:37:31         19
# 4                      Iowa             US  2020-03-24 23:37:31          1
# ...                     ...            ...                  ...        ...
# 10244                   NaN          Syria        3/22/20 23:45          1
# 10245                   NaN    Timor-Leste        3/22/20 23:45          1
# 10246                   NaN         Uganda        3/22/20 23:45          1
# 10247  District of Columbia             US        3/22/20 23:45        102
# 10248            Washington             US        3/22/20 23:45          1
#
#        Deaths  Recovered   Latitude   Longitude
# ...

# %%
df = df.append(df1, ignore_index = True)

# %%
# Unify the time format
df["Last Update"] = pd.to_datetime(df["Last Update"])
# Unify the name of China
df = df.replace(to_replace='Mainland China', value='China', regex=True)
# sort by date
df = df.sort_values(by=['Last Update'])
df
# Out:
#                      Province/State Country/Region         Last Update  \
# 0                             Hunan          China 2020-01-22 17:00:00
# 21                           Taiwan         Taiwan 2020-01-22 17:00:00
# 22                          Sichuan          China 2020-01-22 17:00:00
# 23                           Shanxi          China 2020-01-22 17:00:00
# 24                         Shanghai          China 2020-01-22 17:00:00
# ...                             ...            ...                 ...
# 11227               South Australia      Australia 2020-03-24 23:41:50
# 11160  Australian Capital Territory      Australia 2020-03-24 23:41:50
# 11204               New South Wales      Australia 2020-03-24 23:41:50
# 11229                      Tasmania      Australia 2020-03-24 23:41:50
# 11208            Northern Territory      Australia 2020-03-24 23:41:50
#
#        Confirmed  Deaths  Recovered  Latitude  Longitude
# 0            4.0     NaN        NaN       NaN        NaN
# ...

# %%
df.drop_duplicates(keep = False, inplace = True)

# %%
df
# Out:
#                      Province/State Country/Region         Last Update  \
# 0                             Hunan          China 2020-01-22 17:00:00
# 21                           Taiwan         Taiwan 2020-01-22 17:00:00
# 22                          Sichuan          China 2020-01-22 17:00:00
# 23                           Shanxi          China 2020-01-22 17:00:00
# 24                         Shanghai          China 2020-01-22 17:00:00
# ...                             ...            ...                 ...
# 11227               South Australia      Australia 2020-03-24 23:41:50
# 11160  Australian Capital Territory      Australia 2020-03-24 23:41:50
# 11204               New South Wales      Australia 2020-03-24 23:41:50
# 11229                      Tasmania      Australia 2020-03-24 23:41:50
# 11208            Northern Territory      Australia 2020-03-24 23:41:50
#
#        Confirmed  Deaths  Recovered  Latitude  Longitude
# 0            4.0     NaN        NaN       NaN        NaN
# ...

# %%
df.to_csv("/Users/Fox/Desktop/Data Science/Data Visualization/Project2/Data/Consolidation.csv",index=None)
